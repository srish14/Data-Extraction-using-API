# %%
import requests
import pandas as pd
from prettytable import PrettyTable
import json

# %%
#pretty table object
tableobj = PrettyTable()

# %% [markdown]
# Store API Key in a variable & concatenate it with API endpoint

# %%
KeyVal = 'be89bc32-256e-4188-9734-311fd8128c1e'

api_endpoint = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY='
api_endpoint += KeyVal
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=be89bc32-256e-4188-9734-311fd8128c1e'

# %%
jason_data = requests.get(api_endpoint).json()

# %%
cryptodata = jason_data['data']

# %%
requests.get(api_endpoint).json()
# Out:
# {'status': {'timestamp': '2021-06-24T14:05:08.114Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 17,
#   'credit_count': 1,
#   'notice': None,
#   'total_count': 5430},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 9189,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channels',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures',
#     'galaxy-digital-portfolio',
#     'huobi-capital',
#     'alameda-research-portfolio',
# ...

# %% [markdown]
# Storing Data in Pretty Table

# %%
#From above data we will traverse through data for fetching following values
for currency in cryptodata:
    curr_name = currency['name'] #name of currency
    curr_price = currency['quote']['USD']['price']
    curr_change_1h = currency['quote']['USD']['percent_change_1h'] #currency change
    curr_change_24h = currency['quote']['USD']['percent_change_24h']
    curr_change_7d = currency['quote']['USD']['percent_change_7d']
    #table is created to save the values as rows
    tableobj.add_row([curr_name, curr_price, curr_change_1h, curr_change_24h, curr_change_7d])

# %% [markdown]
# Create external Field names and assign as column names in Pretty table

# %%
tableobj.field_names =  ["Currency Name", "Currency Price", "Currency 1h Change", "Currency 24h change", "Currency 7d change"]
print(tableobj)
# Out:
# +-----------------------+--------------------+--------------------+---------------------+--------------------+
# |     Currency Name     |   Currency Price   | Currency 1h Change | Currency 24h change | Currency 7d change |
# +-----------------------+--------------------+--------------------+---------------------+--------------------+
# |        Bitcoin        | 34020.966653977855 |    -0.06413345     |     -0.25154198     |    -11.9696954     |
# |        Ethereum       | 1967.3154359316397 |    -0.49029965     |     -1.67413824     |    -17.14731297    |
# |         Tether        |  1.00012928151725  |    -0.02232236     |     -0.09243888     |    -0.00610081     |
# |      Binance Coin     | 304.58134815381123 |    -0.50077356     |      1.26884967     |    -13.59403743    |
# |        Cardano        |  1.35496448490236  |    -0.23631296     |      6.0758662      |    -9.23604134     |
# ...

# %% [markdown]
# Store data in text file format

# %%
table_txt = tableobj.get_string()
with open('output.txt', 'w') as file:
    file.write(table_txt)
    
#A file will be created in the directory where this program is saved
